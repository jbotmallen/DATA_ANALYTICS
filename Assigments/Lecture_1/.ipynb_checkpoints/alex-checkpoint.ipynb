# %% [markdown]
# # Balanced risk set matching implementation on OASIS dataset
# Submitted by: Alex Abainza & Mark Allen Jugalbot<br/>
# CS3203 Data Analytics

# %% [markdown]
# ## Reading dataset

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("oasis_dataset.csv")
df.head()
# Out:
#    entry_number subject_id  visit  time_of_ad m_f  educ  ses  age  mr_delay  \
# 0             1  OAS2_0002      1         NaN   M    12   -1   75         0
# 1             2  OAS2_0002      2         NaN   M    12   -1   76       560
# 2             3  OAS2_0002      3         NaN   M    12   -1   80      1895
# 3             4  OAS2_0007      1         3.0   M    16   -1   71         0
# 4             5  OAS2_0007      3         3.0   M    16   -1   73       518
#
#    e_tiv  n_wbv    asf
# 0   1678  0.736  1.046
# 1   1738  0.713  1.010
# 2   1698  0.701  1.034
# 3   1357  0.748  1.293
# 4   1365  0.727  1.286

# %%
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   entry_number  115 non-null    int64
#  1   subject_id    115 non-null    object
#  2   visit         115 non-null    int64
#  3   time_of_ad    29 non-null     float64
#  4   m_f           115 non-null    object
#  5   educ          115 non-null    int64
#  6   ses           115 non-null    int64
#  7   age           115 non-null    int64
#  8   mr_delay      115 non-null    int64
#  9   e_tiv         115 non-null    int64
#  10  n_wbv         115 non-null    float64
#  11  asf           115 non-null    float64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 10.9+ KB
#    entry_number subject_id  visit  time_of_ad m_f  educ  ses  age  mr_delay  \
# 0             1  OAS2_0002      1         NaN   M    12   -1   75         0
# 1             2  OAS2_0002      2         NaN   M    12   -1   76       560
# 2             3  OAS2_0002      3         NaN   M    12   -1   80      1895
# 3             4  OAS2_0007      1         3.0   M    16   -1   71         0
# 4             5  OAS2_0007      3         3.0   M    16   -1   73       518
# 5             6  OAS2_0007      4         3.0   M    16   -1   75      1281
# 6             7  OAS2_0009      1         NaN   M    12    2   68         0
# 7             8  OAS2_0009      2         NaN   M    12    2   69       576
# 8             9  OAS2_0010      1         NaN   F    12    3   66         0
# 9            10  OAS2_0010      2         NaN   F    12    3   68       854
#
#    e_tiv  n_wbv    asf
# 0   1678  0.736  1.046
# 1   1738  0.713  1.010
# 2   1698  0.701  1.034
# 3   1357  0.748  1.293
# 4   1365  0.727  1.286
# 5   1372  0.710  1.279
# 6   1457  0.806  1.205
# 7   1480  0.791  1.186
# 8   1447  0.769  1.213
# 9   1482  0.752  1.184

# %% [markdown]
# ## Data Preprocessing

# %%
df.drop(columns=["entry_number"], inplace=True)

# %%
df.head()
# Out:
#   subject_id  visit  time_of_ad m_f  educ  ses  age  mr_delay  e_tiv  n_wbv  \
# 0  OAS2_0002      1         NaN   M    12   -1   75         0   1678  0.736
# 1  OAS2_0002      2         NaN   M    12   -1   76       560   1738  0.713
# 2  OAS2_0002      3         NaN   M    12   -1   80      1895   1698  0.701
# 3  OAS2_0007      1         3.0   M    16   -1   71         0   1357  0.748
# 4  OAS2_0007      3         3.0   M    16   -1   73       518   1365  0.727
#
#      asf
# 0  1.046
# 1  1.010
# 2  1.034
# 3  1.293
# 4  1.286

# %%
df.sort_values(by=["subject_id", "visit"], inplace=True)
df["m_f"] = df["m_f"].astype("category")

# %%
print(df['ses'].value_counts())
# ses values which are -1 are likely empty
df["ses"] = df["ses"].replace(-1, np.nan)
# Out:
# ses
#  4    31
#  3    29
# -1    19
#  2    19
#  1    15
#  5     2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   subject_id  visit  time_of_ad m_f  educ  ses  age  mr_delay  e_tiv  n_wbv  \
# 0  OAS2_0002      1         NaN   M    12  NaN   75         0   1678  0.736
# 1  OAS2_0002      2         NaN   M    12  NaN   76       560   1738  0.713
# 2  OAS2_0002      3         NaN   M    12  NaN   80      1895   1698  0.701
# 3  OAS2_0007      1         3.0   M    16  NaN   71         0   1357  0.748
# 4  OAS2_0007      3         3.0   M    16  NaN   73       518   1365  0.727
#
#      asf
# 0  1.046
# 1  1.010
# 2  1.034
# 3  1.293
# 4  1.286

# %%
age_stats = df["age"].describe()
educ_stats = df["educ"].describe()

age_stats, educ_stats
# Out:
# (count    115.000000
#  mean      76.400000
#  std        6.495342
#  min       62.000000
#  25%       72.000000
#  50%       76.000000
#  75%       81.000000
#  max       92.000000
#  Name: age, dtype: float64,
#  count    115.000000
#  mean      13.582609
#  std        2.837662
#  min        6.000000
#  25%       12.000000
#  50%       12.000000
#  75%       16.000000
#  max       20.000000
#  Name: educ, dtype: float64)

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# subject_id     0
# visit          0
# time_of_ad    86
# m_f            0
# educ           0
# ses           19
# age            0
# mr_delay       0
# e_tiv          0
# n_wbv          0
# asf            0
# dtype: int64

# %%
# identify patients who had a change of time of ad - likely to have been diagnosed
df["is_diagnosed"] = np.where(df["time_of_ad"].isin([2, 3]), 1, 0)

# %%
df = df.rename(columns={
    'subject_id': 'participant_id',
    'visit': 'visit_number',
    'time_of_ad': 'assessment_time',
    'm_f': 'gender',
    'educ': 'education_years',
    'ses': 'socioeconomic_status',
    'age': 'age_at_visit',
    'mr_delay': 'mri_scan_delay',
    'e_tiv': 'estimated_total_intracranial_volume',
    'n_wbv': 'normalized_brain_volume',
    'asf': 'atlas_scaling_factor',
    'is_diagnosed': 'diagnosed'
})

# %%
df["gender"] = df["gender"].map({"F":0, "M":1})

# %%
df.head(20)
# Out:
#    participant_id  visit_number  assessment_time gender  education_years  \
# 0       OAS2_0002             1              NaN      1               12
# 1       OAS2_0002             2              NaN      1               12
# 2       OAS2_0002             3              NaN      1               12
# 3       OAS2_0007             1              3.0      1               16
# 4       OAS2_0007             3              3.0      1               16
# 5       OAS2_0007             4              3.0      1               16
# 6       OAS2_0009             1              NaN      1               12
# 7       OAS2_0009             2              NaN      1               12
# 8       OAS2_0010             1              NaN      0               12
# 9       OAS2_0010             2              NaN      0               12
# 10      OAS2_0014             1              2.0      1               16
# 11      OAS2_0014             2              2.0      1               16
# 12      OAS2_0016             1              NaN      1                8
# 13      OAS2_0016             2              NaN      1                8
# 14      OAS2_0021             1              NaN      1               20
# 15      OAS2_0021             2              NaN      1               20
# 16      OAS2_0023             1              NaN      0               12
# 17      OAS2_0023             2              NaN      0               12
# 18      OAS2_0026             1              NaN      1               12
# 19      OAS2_0026             2              NaN      1               12
#
#     socioeconomic_status  age_at_visit  mri_scan_delay  \
# 0                    NaN            75               0
# 1                    NaN            76             560
# 2                    NaN            80            1895
# 3                    NaN            71               0
# 4                    NaN            73             518
# 5                    NaN            75            1281
# 6                    2.0            68               0
# 7                    2.0            69             576
# 8                    3.0            66               0
# 9                    3.0            68             854
# 10                   3.0            76               0
# 11                   3.0            77             504
# 12                   4.0            88               0
# 13                   4.0            90             707
# 14                   1.0            72               0
# 15                   1.0            76            1164
# 16                   4.0            86               0
# 17                   4.0            87             578
# 18                   3.0            82               0
# 19                   3.0            84             673
#
#     estimated_total_intracranial_volume  normalized_brain_volume  \
# 0                                  1678                    0.736
# 1                                  1738                    0.713
# 2                                  1698                    0.701
# 3                                  1357                    0.748
# 4                                  1365                    0.727
# 5                                  1372                    0.710
# 6                                  1457                    0.806
# 7                                  1480                    0.791
# 8                                  1447                    0.769
# 9                                  1482                    0.752
# 10                                 1602                    0.697
# 11                                 1590                    0.696
# 12                                 1651                    0.660
# 13                                 1668                    0.646
# 14                                 1911                    0.719
# 15                                 1926                    0.736
# 16                                 1247                    0.662
# 17                                 1250                    0.652
# 18                                 1420                    0.713
# 19                                 1445                    0.695
#
#     atlas_scaling_factor  diagnosed
# 0                  1.046          0
# 1                  1.010          0
# 2                  1.034          0
# 3                  1.293          1
# 4                  1.286          1
# 5                  1.279          1
# 6                  1.205          0
# 7                  1.186          0
# 8                  1.213          0
# 9                  1.184          0
# 10                 1.096          1
# 11                 1.104          1
# 12                 1.063          0
# 13                 1.052          0
# 14                 0.919          0
# 15                 0.911          0
# 16                 1.407          0
# 17                 1.405          0
# 18                 1.236          0
# 19                 1.214          0

# %% [markdown]
# ## Mini EDA

# %%
categorical_vars = ["gender", "socioeconomic_status"]
discrete_vars = ['education_years', 'age_at_visit']
continuous_vars = ['estimated_total_intracranial_volume', 'normalized_brain_volume', 'atlas_scaling_factor']
p_values = {}

# %% [markdown]
# ### On categorical values (gender, socioeconomic status)
# Using continuous variables (e.g. estimated_total_intracranial_volume, normalized_brain_volume, atlas_scaling_factor

# %%
for var in categorical_vars:
    contingency_table = pd.crosstab(df[var], df['diagnosed'])
    chi2, p, dof, expected = stats.chi2_contingency(contingency_table)
    p_values[var] = p

# %% [markdown]
# ### On discrete and categorical values

# %%
for var in discrete_vars + continuous_vars:
    t_stat, p = stats.ttest_ind(df[df['diagnosed'] == 1][var], df[df['diagnosed'] == 0][var], equal_var=False)
    p_values[var] = p

# %%
formula = "diagnosed ~ " + " + ".join(categorical_vars + discrete_vars + continuous_vars)
logit_model = smf.logit(formula, data=df).fit()
logit_p_values = logit_model.pvalues.to_dict()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.352171
#          Iterations 10

# %%
results_df = pd.DataFrame({
    'Variable': list(p_values.keys()),
    'P-Value (T-Test/Chi-Square)': list(p_values.values()),
    'P-Value (Logistic Regression)': [logit_p_values.get(var, None) for var in p_values.keys()]
})

# Add significance flag
results_df['Significant? (p < 0.05)'] = results_df.apply(lambda row: '✅ Yes' if row['P-Value (T-Test/Chi-Square)'] < 0.05 or row['P-Value (Logistic Regression)'] < 0.05 else '🚫 No', axis=1)

# Display results
print(results_df)
# Out:
#                               Variable  P-Value (T-Test/Chi-Square)  \
# 0                               gender                     0.343671
# 1                 socioeconomic_status                     0.587134
# 2                      education_years                     0.475551
# 3                         age_at_visit                     0.001287
# 4  estimated_total_intracranial_volume                     0.073508
# 5              normalized_brain_volume                     0.372852
# 6                 atlas_scaling_factor                     0.147997
#
#    P-Value (Logistic Regression) Significant? (p < 0.05)
# 0                            NaN                    🚫 No
# 1                       0.681475                    🚫 No
# 2                       0.330006                    🚫 No
# 3                       0.008011                   ✅ Yes
# 4                       0.073679                    🚫 No
# 5                       0.008984                   ✅ Yes
# 6                       0.059921                    🚫 No

# %%
volume_cols = [
    'participant_id', 'diagnosed', 
    'estimated_total_intracranial_volume', 'normalized_brain_volume', 'atlas_scaling_factor'
]

df_avg =  df[volume_cols].groupby(["participant_id", "diagnosed"]).mean().reset_index()
df_diagnosed = df_avg[df_avg['diagnosed'] == 1]
df_undiagnosed = df_avg[df_avg['diagnosed'] == 0]

# %%
# Function to get descriptive stats
def get_summary_stats(df, label):
    print(f"\n📊 Summary Statistics for {label} Patients:\n")
    stats = df.describe().T[['mean', 'std', 'min', '25%', '50%', '75%', 'max']]
    print(stats)

# Get stats for diagnosed and undiagnosed groups
get_summary_stats(df_diagnosed, "Diagnosed")
get_summary_stats(df_undiagnosed, "Undiagnosed")
# Out:
# 📊 Summary Statistics for Diagnosed Patients:
#
#                                             mean         std          min  \
# diagnosed                               1.000000    0.000000     1.000000
# estimated_total_intracranial_volume  1436.948718  123.946886  1166.333333
# normalized_brain_volume                 0.716269    0.018003     0.688000
# atlas_scaling_factor                    1.230372    0.113567     1.100000
#
#                                            25%       50%        75%       max
# diagnosed                               1.0000     1.000     1.0000     1.000
# estimated_total_intracranial_volume  1352.5000  1472.000  1554.5000  1596.000
# normalized_brain_volume                 0.7045     0.718     0.7270     0.749
# atlas_scaling_factor                    1.1290     1.193     1.2975     1.505
#
# 📊 Summary Statistics for Undiagnosed Patients:
#
#                                             mean         std       min  \
# diagnosed                               0.000000    0.000000     0.000
# estimated_total_intracranial_volume  1475.894737  182.079939  1147.000
# normalized_brain_volume                 0.724208    0.035375     0.653
# atlas_scaling_factor                    1.206375    0.145095     0.915
#
#                                              25%          50%          75%  \
# diagnosed                               0.000000     0.000000     0.000000
# estimated_total_intracranial_volume  1330.375000  1466.500000  1551.500000
# normalized_brain_volume                 0.698000     0.721333     0.749500
# atlas_scaling_factor                    1.131333     1.197000     1.319375
#
#                                            max
# diagnosed                               0.0000
# estimated_total_intracranial_volume  1918.5000
# normalized_brain_volume                 0.7985
# atlas_scaling_factor                    1.5300

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style("whitegrid")

# Plot histograms for each variable
for col in ['estimated_total_intracranial_volume', 'normalized_brain_volume', 'atlas_scaling_factor']:
    plt.figure(figsize=(8, 5))
    sns.kdeplot(df_diagnosed[col], label="Diagnosed", fill=True, alpha=0.5)
    sns.kdeplot(df_undiagnosed[col], label="Undiagnosed", fill=True, alpha=0.5)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel("Density")
    plt.legend()
    plt.show()

# %%
from scipy.stats import ttest_ind

# Perform t-tests
for col in ['estimated_total_intracranial_volume', 'normalized_brain_volume', 'atlas_scaling_factor']:
    t_stat, p_value = ttest_ind(df_diagnosed[col], df_undiagnosed[col], equal_var=False)
    print(f"\n📌 T-test for {col}:")
    print(f"   - T-statistic: {t_stat:.3f}")
    print(f"   - P-value: {p_value:.5f} {'(Significant)' if p_value < 0.05 else '(Not Significant)'}")
# Out:
# 📌 T-test for estimated_total_intracranial_volume:
#    - T-statistic: -0.859
#    - P-value: 0.39682 (Not Significant)
#
# 📌 T-test for normalized_brain_volume:
#    - T-statistic: -1.044
#    - P-value: 0.30270 (Not Significant)
#
# 📌 T-test for atlas_scaling_factor:
#    - T-statistic: 0.610
#    - P-value: 0.54688 (Not Significant)

# %% [markdown]
# Using discrete variables

# %%
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm

# Select categorical variables
categorical_vars = ['gender', 'socioeconomic_status']  # Add more if applicable

# Create a table of diagnosis counts per category
for var in categorical_vars:
    print(f"\n📌 Frequency Table for {var} vs. Diagnosis:")
    print(pd.crosstab(df[var], df['diagnosed']))
# Out:
# 📌 Frequency Table for gender vs. Diagnosis:
# diagnosed   0   1
# gender
# 0          31  14
# 1          55  15
#
# 📌 Frequency Table for socioeconomic_status vs. Diagnosis:
# diagnosed              0  1
# socioeconomic_status
# 1.0                   13  2
# 2.0                   13  6
# 3.0                   23  6
# 4.0                   26  5
# 5.0                    2  0

# %%
# Chi-Square Test for Independence
for var in categorical_vars:
    contingency_table = pd.crosstab(df[var], df['diagnosed'])
    chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

    print(f"\n📊 Chi-Square Test for {var}:")
    print(f"   - Chi2 Statistic: {chi2:.3f}")
    print(f"   - P-value: {p:.5f} {'(Significant)' if p < 0.05 else '(Not Significant)'}")
# Out:
# 📊 Chi-Square Test for gender:
#    - Chi2 Statistic: 0.897
#    - P-value: 0.34367 (Not Significant)
#
# 📊 Chi-Square Test for socioeconomic_status:
#    - Chi2 Statistic: 2.827
#    - P-value: 0.58713 (Not Significant)

# %%
import statsmodels.formula.api as smf

# Build logistic regression model
formula = "diagnosed ~ " + " + ".join(categorical_vars)
logit_model = smf.logit(formula, data=df).fit()

# Print summary
print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.489586
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              diagnosed   No. Observations:                   96
# Model:                          Logit   Df Residuals:                       93
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 01 Feb 2025   Pseudo R-squ.:                 0.01591
# Time:                        13:38:04   Log-Likelihood:                -47.000
# converged:                       True   LL-Null:                       -47.760
# Covariance Type:            nonrobust   LLR p-value:                    0.4677
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               -0.5414      0.834     -0.650      0.516      -2.175       1.092
# gender[T.1]             -0.5997      0.535     -1.121      0.262      -1.649       0.449
# socioeconomic_status    -0.1798      0.241     -0.745      0.457      -0.653       0.293
# ========================================================================================

# %%
from scipy.stats import ttest_ind

# List of continuous variables to test
continuous_vars = ['age_at_visit', 'education_years']

# Perform t-tests
for col in continuous_vars:
    t_stat, p_value = ttest_ind(df[df['diagnosed'] == 1][col], df[df['diagnosed'] == 0][col], equal_var=False)
    print(f"\n📌 T-test for {col}:")
    print(f"   - T-statistic: {t_stat:.3f}")
    print(f"   - P-value: {p_value:.5f} {'(Significant)' if p_value < 0.05 else '(Not Significant)'}")
# Out:
# 📌 T-test for age_at_visit:
#    - T-statistic: -3.343
#    - P-value: 0.00129 (Significant)
#
# 📌 T-test for education_years:
#    - T-statistic: 0.718
#    - P-value: 0.47555 (Not Significant)

# %%
import statsmodels.formula.api as smf

# Build logistic regression model
formula = "diagnosed ~ age_at_visit + education_years"
logit_model = smf.logit(formula, data=df).fit()

# Print summary
print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.532506
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              diagnosed   No. Observations:                  115
# Model:                          Logit   Df Residuals:                      112
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 01 Feb 2025   Pseudo R-squ.:                 0.05703
# Time:                        13:42:17   Log-Likelihood:                -61.238
# converged:                       True   LL-Null:                       -64.942
# Covariance Type:            nonrobust   LLR p-value:                   0.02463
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           5.9059      3.167      1.865      0.062      -0.302      12.113
# age_at_visit       -0.0958      0.038     -2.519      0.012      -0.170      -0.021
# education_years     0.0171      0.083      0.206      0.837      -0.146       0.180
# ===================================================================================

# %% [markdown]
# ## Performing balanced risk set matching
